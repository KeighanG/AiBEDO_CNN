# %%
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt  #for plotting purpose
import sklearn

# %%
import xcast
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 import xcast
#
# File <frozen zipimport>:259, in load_module(self, fullname)
#
# File ~/.conda/envs/xcast_env/lib/python3.8/site-packages/xcast-0.3.3-py3.8.egg/xcast/__init__.py:1, in <module>
# ----> 1 from .classification import *
#       2 from .core import *
#       3 from .flat_estimators import *
#
# File <frozen zipimport>:259, in load_module(self, fullname)
#
# File ~/.conda/envs/xcast_env/lib/python3.8/site-packages/xcast-0.3.3-py3.8.egg/xcast/classification/__init__.py:1, in <module>
# ----> 1 from .base_classifier import *
#       2 from .classifiers import *
#       5 tercile_classifiers = [eLogisticRegression, eMultivariateLogisticRegression, eRandomForest, eNaiveBayes, eMultiLayerPerceptron, ePOELM]
#
# File <frozen zipimport>:259, in load_module(self, fullname)
#
# ...

# %%
model_ols =  linear_model.LinearRegression(normalize=True)
#model_ols.fit(X,y)

# %%
inputF=xr.open_dataset('../moved_files/Experiments_input/Exp7_CESM2_r1i1p1f1_historical_Input.nc')
outputF=xr.open_dataset('../moved_files/Experiments_input/Exp5_CESM2_r1i1p1f1_historical_Output.nc')
inputF
# Out:
# <xarray.Dataset>
# Dimensions:        (time: 1980, lat: 192, lon: 288)
# Coordinates:
#   * time           (time) object 1850-01-15 12:00:00 ... 2014-12-15 12:00:00
#   * lat            (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * lon            (lon) float64 0.0 1.25 2.5 3.75 ... 355.0 356.2 357.5 358.8
# Data variables: (12/18)
#     cres_pre       (time, lat, lon) float64 ...
#     cres           (time, lat, lon) float32 ...
#     crel_Pre       (time, lat, lon) float64 ...
#     crel           (time, lat, lon) float32 ...
#     netTOAcs_Pre   (time, lat, lon) float64 ...
#     netTOAcs       (time, lat, lon) float32 ...
#     ...             ...
#     cresSurf_Pre   (time, lat, lon) float64 ...
#     cresSurf       (time, lat, lon) float32 ...
#     crelSurf_Pre   (time, lat, lon) float64 ...
#     crelSurf       (time, lat, lon) float32 ...
#     netSurfcs_Pre  (time, lat, lon) float64 ...
#     netSurfcs      (time, lat, lon) float32 ...

# %%
inputD=inputF.drop_vars(['cres','crel','netTOAcs','clivi','clwvi','lcloud','cresSurf','crelSurf','netSurfcs'])
inputD
# Out:
# <xarray.Dataset>
# Dimensions:        (time: 1980, lat: 192, lon: 288)
# Coordinates:
#   * time           (time) object 1850-01-15 12:00:00 ... 2014-12-15 12:00:00
#   * lat            (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * lon            (lon) float64 0.0 1.25 2.5 3.75 ... 355.0 356.2 357.5 358.8
# Data variables:
#     cres_pre       (time, lat, lon) float64 ...
#     crel_Pre       (time, lat, lon) float64 ...
#     netTOAcs_Pre   (time, lat, lon) float64 ...
#     clivi_pre      (time, lat, lon) float64 ...
#     clwvi_pre      (time, lat, lon) float64 ...
#     lcloud_pre     (time, lat, lon) float64 ...
#     cresSurf_Pre   (time, lat, lon) float64 ...
#     crelSurf_Pre   (time, lat, lon) float64 ...
#     netSurfcs_Pre  (time, lat, lon) float64 ...

# %%
outTas=outputF.tas_pre
outTas
# Out:
# <xarray.DataArray 'tas_pre' (time: 1980, lat: 192, lon: 288)>
# [109486080 values with dtype=float64]
# Coordinates:
#   * time     (time) object 1850-01-15 12:00:00 ... 2014-12-15 12:00:00
#   * lat      (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 87.17 88.12 89.06 90.0
#   * lon      (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
# Attributes:
#     long_name:  Processed Near-Surface Air Temperature
#     units:      K

# %%
wrapper = wrap(linear_model.LinearRegression())
#.fit(inputD,outTas)
#Xt
wrapper.fit(inputD,outTas)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [23], in <module>
#       1 wrapper = wrap(linear_model.LinearRegression())
#       2 #.fit(inputD,outTas)
#       3 #Xt
# ----> 4 wrapper.fit(inputD,outTas)
#
# File ~/.conda/envs/python3.9/lib/python3.9/site-packages/sklearn_xarray/common/wrappers.py:280, in EstimatorWrapper.fit(self, X, y, **fit_params)
#     277 elif is_dataset(X):
#     279     self.type_ = "Dataset"
# --> 280     self.estimator_dict_ = {
#     281         v: self._fit(X[v], y, **fit_params) for v in X.data_vars
#     282     }
#     284     # TODO: check if this needs to be removed for compat wrappers
#     285     for e_name, e in six.iteritems(self.estimator_dict_):
#
# File ~/.conda/envs/python3.9/lib/python3.9/site-packages/sklearn_xarray/common/wrappers.py:281, in <dictcomp>(.0)
#     277 elif is_dataset(X):
# ...
